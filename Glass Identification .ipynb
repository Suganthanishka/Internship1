# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv")

# %%
df.head(15)
# Out:
#      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0    2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1    3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2    4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3    5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4    6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1
# 5    7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17   0.0    0.00    1
# 6    8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24   0.0    0.00    1
# 7    9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30   0.0    0.00    1
# 8   10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40   0.0    0.11    1
# 9   11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09   0.0    0.24    1
# 10  12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56   0.0    0.00    1
# 11  13  1.51589  12.88  3.43  1.40  73.28  0.69  8.05   0.0    0.24    1
# ...

# %%
df.tail(15)
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 198  200  1.51609  15.01   0.0  2.51  73.05  0.05  8.83  0.53     0.0    7
# 199  201  1.51508  15.15   0.0  2.25  73.50  0.00  8.34  0.63     0.0    7
# 200  202  1.51653  11.95   0.0  1.19  75.18  2.70  8.93  0.00     0.0    7
# 201  203  1.51514  14.85   0.0  2.42  73.72  0.00  8.39  0.56     0.0    7
# 202  204  1.51658  14.80   0.0  1.99  73.11  0.00  8.28  1.71     0.0    7
# 203  205  1.51617  14.95   0.0  2.27  73.30  0.00  8.71  0.67     0.0    7
# 204  206  1.51732  14.95   0.0  1.80  72.99  0.00  8.61  1.55     0.0    7
# 205  207  1.51645  14.94   0.0  1.87  73.11  0.00  8.67  1.38     0.0    7
# 206  208  1.51831  14.39   0.0  1.82  72.86  1.41  6.47  2.88     0.0    7
# 207  209  1.51640  14.37   0.0  2.74  72.85  0.00  9.45  0.54     0.0    7
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# ...

# %%
df.shape
# Out:
# (213, 11)

# %%
df.columns.tolist()
# Out:
# ['1',
#  '1.52101',
#  '13.64',
#  '4.49',
#  '1.10',
#  '71.78',
#  '0.06',
#  '8.75',
#  '0.00',
#  '0.00.1',
#  '1.1']

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        213 non-null    int64
#  1   1.52101  213 non-null    float64
#  2   13.64    213 non-null    float64
#  3   4.49     213 non-null    float64
#  4   1.10     213 non-null    float64
#  5   71.78    213 non-null    float64
#  6   0.06     213 non-null    float64
#  7   8.75     213 non-null    float64
#  8   0.00     213 non-null    float64
#  9   0.00.1   213 non-null    float64
#  10  1.1      213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
df.describe()
# Out:
#                 1     1.52101       13.64        4.49        1.10       71.78  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#              0.06        8.75        0.00      0.00.1         1.1
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     0.499108    8.957934    0.175869    0.057277    2.788732
# std      0.653035    1.426435    0.498245    0.097589    2.105130
# ...

# %%
df.skew()
# Out:
# 1          0.000000
# 1.52101    1.639658
# 13.64      0.457318
# 4.49      -1.154323
# 1.10       0.900017
# 71.78     -0.744546
# 0.06       6.549276
# 8.75       2.040591
# 0.00       3.406749
# 0.00.1     1.747173
# 1.1        1.108861
# dtype: float64

# %%
df.dtypes
# Out:
# 1            int64
# 1.52101    float64
# 13.64      float64
# 4.49       float64
# 1.10       float64
# 71.78      float64
# 0.06       float64
# 8.75       float64
# 0.00       float64
# 0.00.1     float64
# 1.1          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
df.shape[0]
# Out:
# 213

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 2      1
# 136    1
# 138    1
# 139    1
# 140    1
#       ..
# 76     1
# 77     1
# 78     1
# 79     1
# 214    1
# Name: 1, Length: 213, dtype: int64
#
#
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51761    2
# 1.51613    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: 1.52101, Length: 177, dtype: int64
#
#
# 13.21    5
# 13.02    5
# 13.00    5
# 12.85    4
# 12.86    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: 13.64, Length: 142, dtype: int64
#
#
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 3.46     1
# 3.73     1
# 3.97     1
# 3.89     1
# 1.78     1
# Name: 4.49, Length: 93, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.56    5
# 1.29    5
# 1.43    5
#        ..
# 1.61    1
# 0.88    1
# 1.05    1
# 0.65    1
# 1.94    1
# Name: 1.10, Length: 117, dtype: int64
#
#
# 72.99    4
# 73.10    4
# 72.86    4
# 73.28    4
# 73.11    4
# ...

# %%
names_columns=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Types of glass']
df.columns=names_columns
df.head()
# Out:
#    Id       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  \
# 0   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00
# 1   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00
# 2   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00
# 3   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00
# 4   6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26
#
#    Types of glass
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
df=df.drop('Id',1)

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Types of glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00               1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00               1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00               1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00               1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26               1

# %%
sns.heatmap(df.isnull(),cmap="cool_r")
# Out:
# <Axes: >

# %%
df.iloc[8:]
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Types of glass
# 8    1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00  0.11               1
# 9    1.51571  12.72  3.46  1.56  73.20  0.67  8.09  0.00  0.24               1
# 10   1.51763  12.80  3.66  1.27  73.01  0.60  8.56  0.00  0.00               1
# 11   1.51589  12.88  3.43  1.40  73.28  0.69  8.05  0.00  0.24               1
# 12   1.51748  12.86  3.56  1.27  73.21  0.54  8.38  0.00  0.17               1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...             ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00               7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00               7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00               7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00               7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00               7
#
# [205 rows x 10 columns]

# %%
df.nunique().to_frame("no of unique values")
# Out:
#                 no of unique values
# RI                              177
# Na                              142
# Mg                               93
# Al                              117
# Si                              132
# K                                65
# Ca                              143
# Ba                               34
# Fe                               32
# Types of glass                    6

# %%
ax=sns.countplot(x='Types of glass',data=df)
print(df['Types of glass'].value_counts())
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Types of glass, dtype: int64

# %%
ax=sns.countplot(x='Fe',data=df)
print(df['Fe'].value_counts())
# Out:
# 0.00    143
# 0.24      7
# 0.17      7
# 0.09      6
# 0.10      5
# 0.11      4
# 0.16      3
# 0.28      3
# 0.12      3
# 0.22      3
# 0.14      3
# 0.07      3
# 0.19      2
# 0.15      2
# 0.08      2
# 0.06      1
# 0.21      1
# 0.05      1
# 0.51      1
# 0.37      1
# 0.35      1
# 0.25      1
# 0.18      1
# 0.34      1
# 0.29      1
# 0.30      1
# 0.20      1
# 0.32      1
# 0.26      1
# 0.03      1
# 0.31      1
# 0.01      1
# Name: Fe, dtype: int64

# %%
ax=sns.countplot(x='Mg',data=df)
print(df['Mg'].value_counts())
# Out:
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 3.46     1
# 3.73     1
# 3.97     1
# 3.89     1
# 1.78     1
# Name: Mg, Length: 93, dtype: int64

# %%
plt.figure(figsize=(10,6),facecolor="white")
plotnumber =1
for Mg in Types of glass:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.displot(df[col],color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()
# Out:
#   Cell In[120], line 3
#     for Mg in Types of glass:
#                     ^
# SyntaxError: invalid syntax

# %%
plt.title("comparison between Mg and Types of glass")
sns.stripplot(x="Mg",y="Types of glass",data=df)
plt.show()

# %%
plt.title("comparison between Mg and Types of glass")
sns.scatterplot(x="RI",y="Types of glass",data=df,hue='Mg',palette='bright')
plt.show()

# %%
plt.title("comparison between Mg and Types of glass")
sns.barplot(x="RI",y="Types of glass",data=df,hue='Fe',palette='bright')
plt.show()

# %%
sns.pairplot(df,hue="Types of glass",palette="Dark2")
plt.show()

# %%
df.skew()
# Out:
# RI                1.639658
# Na                0.457318
# Mg               -1.154323
# Al                0.900017
# Si               -0.744546
# K                 6.549276
# Ca                2.040591
# Ba                3.406749
# Fe                1.747173
# Types of glass    1.108861
# dtype: float64

# %%
df['Types of glass']=np.cbrt(df['Types of glass'])
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Types of glass
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00        1.000000
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00        1.000000
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00        1.000000
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00        1.000000
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26        1.000000
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...             ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00        1.241366
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00        1.241366
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00        1.241366
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00        1.241366
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00        1.241366
#
# [213 rows x 10 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='int':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Types of glass
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00        1.000000
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00        1.000000
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00        1.000000
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00        1.000000
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26        1.000000
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...             ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00        1.241366
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00        1.241366
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00        1.241366
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00        1.241366
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00        1.241366
#
# [213 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RI              213 non-null    float64
#  1   Na              213 non-null    float64
#  2   Mg              213 non-null    float64
#  3   Al              213 non-null    float64
#  4   Si              213 non-null    float64
#  5   K               213 non-null    float64
#  6   Ca              213 non-null    float64
#  7   Ba              213 non-null    float64
#  8   Fe              213 non-null    float64
#  9   Types of glass  213 non-null    float64
# dtypes: float64(10)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Types of glass
# count  213.000000  213.000000  213.000000      213.000000
# mean     8.957934    0.175869    0.057277        1.093049
# std      1.426435    0.498245    0.097589        0.085621
# ...

# %%
cor=df.corr()
cor
# Out:
#                       RI        Na        Mg        Al        Si         K  \
# RI              1.000000 -0.193436 -0.128118 -0.405671 -0.540010 -0.287900
# Na             -0.193436  1.000000 -0.276486  0.157928 -0.068519 -0.265520
# Mg             -0.128118 -0.276486  1.000000 -0.480035 -0.160359  0.009397
# Al             -0.405671  0.157928 -0.480035  1.000000 -0.009226  0.324484
# Si             -0.540010 -0.068519 -0.160359 -0.009226  1.000000 -0.197684
# K              -0.287900 -0.265520  0.009397  0.324484 -0.197684  1.000000
# Ca              0.812495 -0.275314 -0.444559 -0.260372 -0.210141 -0.318649
# Ba              0.001062  0.327233 -0.492149  0.478936 -0.104361 -0.043790
# Fe              0.145791 -0.240802  0.086906 -0.076456 -0.097674 -0.009586
# Types of glass -0.148986  0.437739 -0.712310  0.583571  0.116353  0.016328
#
#                       Ca        Ba        Fe  Types of glass
# RI              0.812495  0.001062  0.145791       -0.148986
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),linewidth=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Reds_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['Types of glass'].sort_values(ascending=False)
# Out:
# Types of glass    1.000000
# Al                0.583571
# Ba                0.508303
# Na                0.437739
# Si                0.116353
# Ca                0.031314
# K                 0.016328
# RI               -0.148986
# Fe               -0.155398
# Mg               -0.712310
# Name: Types of glass, dtype: float64

# %%
X=df.drop("Types of glass",axis=1)
Y=df["Types of glass"]

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#       VIF values Features
# 0  723882.657787       RI
# 1   13852.369483       Na
# 2     789.137496       Mg
# 3     174.971317       Al
# 4  366085.917275       Si
# 5      57.016968        K
# 6    8015.051273       Ca
# 7      27.435799       Ba
# 8       1.603762       Fe

# %%
Y.value_counts()
# Out:
# 1.080060    76
# 1.000000    69
# 1.241366    29
# 1.129831    17
# 1.195813    13
# 1.220285     9
# Name: Types of glass, dtype: int64
